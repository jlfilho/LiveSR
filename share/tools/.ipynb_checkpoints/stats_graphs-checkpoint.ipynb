# %% [markdown]
# # Experimental Data Analysis

# %%
import os
import ast
import pandas as pd
import numpy as np
from metrics import parseLogs
from metrics import MetricQoElin
#from metrics import MetricQoEMean as MetricQoElin
import shutil
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Organize logs

# %%
pathgr1 = "../results-collector/scen2-5th/"



files = os.listdir(pathgr1)
    
for file in files:
    if not os.path.isdir(pathgr1+file):
        abr_dir = file.split('_')[1]
        #print(file.split('_')[1])
        if os.path.isdir(pathgr1+abr_dir): 
            shutil.move(pathgr1+file, pathgr1+abr_dir+"/"+file)
        else:
            os.mkdir(pathgr1+abr_dir) 
            shutil.move(pathgr1+file, pathgr1+abr_dir+"/"+file)

# %%
pathgr2 = "../results-collector/scenario2/"
files = os.listdir(pathgr2)
    
for file in files:
    if not os.path.isdir(pathgr2+file):
        abr_dir = file.split('_')[1]
        #print(file.split('_')[1])
        if os.path.isdir(pathgr2+abr_dir): 
            shutil.move(pathgr2+file, pathgr2+abr_dir+"/"+file)
        else:
            os.mkdir(pathgr2+abr_dir) 
            shutil.move(pathgr2+file, pathgr2+abr_dir+"/"+file)

# %% [markdown]
# # 1. QoE Analysis

# %% [markdown]
# ## 1.1 Tabulation QoE

# %%
# Group1 
#700,1600, 2800, 4300 
mi=0.8
lbd=1
mi_s=1.6
div_by=1e6

pathgr1 = "../results-collector/scenario1/"

group1="scenario-1"

metricQoE = MetricQoElin(name=group1,mi=mi, lbd=lbd, mi_s=mi_s,log_level='info')
scores = pd.DataFrame()

listQoE = parseLogs(metricQoE,path = pathgr1+'abrBola/',div_by=div_by) 
scores = metricQoE.tabulation(listQoE,scores = scores,abrRule='BOLA',prefix=group1)

listQoElin = parseLogs(metricQoE,path = pathgr1+'abrL2A/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='L2A-LL',prefix=group1)

listQoElin = parseLogs(metricQoE,path = pathgr1+'abrLoLP/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='LoL+',prefix=group1)
# Out:
# Count segments: 213
# 88.58479999999997
# Count segments: 236
# 402.99120000000005
# Count segments: 172
# 181.51919999999998
# Count segments: 235
# 303.1272
# Count segments: 222
# 173.73360000000008
# Count segments: 249
# 311.1840000000001
# Count segments: 229
# 208.0136000000001
# Count segments: 197
# 40.831999999999994
# Count segments: 195
# 57.200800000000015
# Count segments: 219
# 172.50880000000004
# Count segments: 226
# 173.05200000000008
# Count segments: 217
# 225.44240000000005
# Count segments: 209
# 110.57040000000006
# Count segments: 223
# 304.8344000000001
# Count segments: 227
# 234.6000000000001
# Count segments: 197
# 23.31600000000003
# Count segments: 224
# 89.74239999999998
# Count segments: 220
# 153.3160000000001
# Count segments: 224
# 330.75360000000006
# Count segments: 223
# 154.03839999999997
# Count segments: 224
# 89.65440000000007
# Count segments: 221
# 102.37120000000004
# Count segments: 228
# 162.5016
# Count segments: 212
# 28.192800000000034
# Count segments: 207
# 198.4800000000001
# Count segments: 223
# 291.1184000000002
# Count segments: 220
# 205.53680000000003
# Count segments: 212
# 140.7832000000001
# Count segments: 182
# 201.31760000000003
# Count segments: 217
# 62.43599999999992
# Count segments: 239
# 325.15840000000026
# Count segments: 231
# 207.31999999999996
# Count segments: 195
# 278.16880000000003
# Count segments: 235
# 143.4144
# Count segments: 160
# 95.94319999999996
# Count segments: 153
# 121.82400000000001
# Count segments: 236
# 151.3112
# Count segments: 231
# 141.95120000000003
# Count segments: 63
# 30.0424000000001
# Count segments: 128
# 66.3359999999999
# Count segments: 234
# 145.99199999999996
# Count segments: 237
# 104.99919999999997
# Count segments: 231
# 218.16800000000003
# Count segments: 189
# 2.3687999999999647
# Count segments: 234
# 146.29199999999997
# Count segments: 144
# 183.92320000000007
# Count segments: 135
# 87.32079999999985
# Count segments: 207
# 96.35199999999995
# Count segments: 208
# 220.5888
# Count segments: 232
# 148.74639999999997
# Count segments: 240
# 156.91439999999997
# Count segments: 116
# 25.783999999999992
# Count segments: 238
# 147.84
# Count segments: 161
# 2.987999999999971
# Count segments: 182
# 93.24559999999997
# Count segments: 233
# 136.38959999999994
# Count segments: 204
# 40.813599999999894
# Count segments: 218
# 109.4504
# Count segments: 238
# 152.8456
# Count segments: 238
# 146.04
# Count segments: 188
# 75.38799999999998
# Count segments: 188
# 135.82880000000006
# Count segments: 154
# 211.43759999999992
# Count segments: 233
# 146.0792
# Count segments: 150
# 57.43839999999983
# Count segments: 238
# 145.0128
# Count segments: 227
# 51.6279999999999
# Count segments: 225
# 37.291999999999916
# Count segments: 236
# 237.4527999999999
# Count segments: 222
# 47.91759999999988
# Count segments: 230
# 184.48399999999998
# Count segments: 223
# 61.27119999999982
# Count segments: 237
# 285.1576
# Count segments: 238
# 258.64959999999996
# Count segments: 228
# 171.39679999999993
# Count segments: 237
# 178.2055999999999
# Count segments: 229
# 92.6879999999999
# Count segments: 226
# 57.66719999999995
# Count segments: 238
# 240.63919999999996
# Count segments: 236
# 175.33999999999992
# Count segments: 221
# 136.08319999999998
# Count segments: 232
# 158.5423999999999
# Count segments: 233
# 94.11519999999996
# Count segments: 235
# 282.81440000000003
# Count segments: 224
# 146.5496
# Count segments: 227
# 60.08399999999992
# Count segments: 231
# 154.78799999999978
# Count segments: 235
# 207.05839999999998
# Count segments: 231
# 53.439999999999856
# Count segments: 213
# 112.90399999999994
# Count segments: 232
# 150.6367999999999
# Count segments: 235
# 103.41359999999995
# Count segments: 232
# 205.7464
# Count segments: 227
# 166.00959999999986
# Count segments: 228
# 83.84239999999994
# Count segments: 223
# 32.039999999999935
# Count segments: 234
# 231.73359999999997
# Count segments: 237
# 242.14799999999994
# Count segments: 227
# 107.76399999999998

# %%
pathgr2 = "../results-collector/scenario2/"

group2="scenario-2"

metricQoE = MetricQoElin(name=group2,mi=mi, lbd=lbd, mi_s=mi_s,log_level='info')
#scores = pd.DataFrame()

listQoE = parseLogs(metricQoE,path = pathgr2+'abrBola/',div_by=div_by) 
scores = metricQoE.tabulation(listQoE,scores = scores,abrRule='BOLA',prefix=group2)

listQoElin = parseLogs(metricQoE,path = pathgr2+'abrL2A/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='L2A-LL',prefix=group2)

listQoElin = parseLogs(metricQoE,path = pathgr2+'abrLoLP/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='LoL+',prefix=group2)
# Out:
# Count segments: 230
# 772.5648
# Count segments: 218
# 646.6519999999999
# Count segments: 225
# 785.6711999999998
# Count segments: 233
# 724.0999999999999
# Count segments: 252
# 964.2263999999999
# Count segments: 224
# 772.9327999999998
# Count segments: 231
# 738.9551999999999
# Count segments: 223
# 779.4119999999999
# Count segments: 222
# 688.6623999999999
# Count segments: 225
# 733.5127999999999
# Count segments: 223
# 728.9616000000001
# Count segments: 221
# 593.8392
# Count segments: 221
# 613.2304
# Count segments: 228
# 724.2623999999998
# Count segments: 222
# 543.8352
# Count segments: 226
# 751.7288
# Count segments: 223
# 836.1031999999999
# Count segments: 218
# 808.2479999999998
# Count segments: 227
# 780.7463999999999
# Count segments: 228
# 697.0792
# Count segments: 224
# 789.8055999999998
# Count segments: 223
# 856.5759999999999
# Count segments: 234
# 780.9783999999999
# Count segments: 215
# 648.3320000000001
# Count segments: 214
# 681.1927999999999
# Count segments: 222
# 756.9383999999999
# Count segments: 220
# 707.8415999999999
# Count segments: 224
# 741.1319999999998
# Count segments: 232
# 763.1711999999998
# Count segments: 236
# 806.4719999999998
# Count segments: 220
# 753.2647999999999
# Count segments: 217
# 667.2736
# Count segments: 215
# 541.1800000000001
# Count segments: 230
# 454.0896000000001
# Count segments: 235
# 769.6143999999998
# Count segments: 231
# 915.8023999999998
# Count segments: 219
# 892.5567999999998
# Count segments: 208
# 731.8095999999998
# Count segments: 221
# 150.884
# Count segments: 219
# 825.1111999999998
# Count segments: 229
# 155.27679999999998
# Count segments: 228
# 885.6247999999998
# Count segments: 229
# 907.4831999999998
# Count segments: 194
# 508.6184
# Count segments: 218
# 780.6256
# Count segments: 222
# 890.4495999999998
# Count segments: 210
# 764.5511999999998
# Count segments: 228
# 155.448
# Count segments: 226
# 900.2791999999997
# Count segments: 213
# 511.0599999999999
# Count segments: 223
# 151.64320000000004
# Count segments: 227
# 153.27599999999998
# Count segments: 213
# 447.3791999999999
# Count segments: 206
# 749.4712
# Count segments: 221
# 150.128
# Count segments: 221
# 146.50879999999998
# Count segments: 219
# 794.6159999999999
# Count segments: 226
# 269.2296
# Count segments: 220
# 890.9511999999999
# Count segments: 218
# 215.63039999999998
# Count segments: 231
# 158.0144
# Count segments: 223
# 872.4359999999998
# Count segments: 193
# 661.4655999999999
# Count segments: 225
# 150.32799999999995
# Count segments: 209
# 746.5344
# Count segments: 219
# 146.2768
# Count segments: 206
# 463.34879999999987
# Count segments: 215
# 240.98880000000008
# Count segments: 227
# 154.0544
# Count segments: 229
# 155.9312
# Count segments: 219
# 676.4855999999999
# Count segments: 221
# 721.8287999999999
# Count segments: 216
# 658.3215999999999
# Count segments: 217
# 693.7496
# Count segments: 226
# 617.8128
# Count segments: 229
# 688.344
# Count segments: 221
# 735.9911999999998
# Count segments: 228
# 522.156
# Count segments: 222
# 657.4904
# Count segments: 224
# 478.7632
# Count segments: 228
# 663.8288
# Count segments: 225
# 654.1967999999999
# Count segments: 227
# 745.7815999999999
# Count segments: 221
# 640.9535999999999
# Count segments: 223
# 784.336
# Count segments: 227
# 783.6839999999999
# Count segments: 220
# 701.1575999999999
# Count segments: 220
# 750.6904
# Count segments: 217
# 513.4336000000001
# Count segments: 230
# 695.8960000000001
# Count segments: 224
# 694.4543999999999
# Count segments: 231
# 839.9791999999999
# Count segments: 220
# 720.4744
# Count segments: 210
# 368.7632
# Count segments: 230
# 574.088
# Count segments: 226
# 783.2231999999999
# Count segments: 221
# 478.8664
# Count segments: 236
# 772.8135999999998
# Count segments: 222
# 636.0239999999999
# Count segments: 225
# 697.9295999999999
# Count segments: 229
# 750.2215999999999
# Count segments: 225
# 648.5952
# Count segments: 223
# 758.6143999999999
# Count segments: 229
# 757.8847999999998
# Count segments: 215
# 650.2288

# %%
pathgr3 = "../results-collector/scenario3/" 

group3="scenario-3"

metricQoE = MetricQoElin(name=group3,mi=mi, lbd=lbd, mi_s=mi_s,log_level='info')
#scores = pd.DataFrame()

listQoE = parseLogs(metricQoE,path = pathgr3+'abrBola/',div_by=div_by) 
scores = metricQoE.tabulation(listQoE,scores = scores,abrRule='BOLA',prefix=group3)

listQoElin = parseLogs(metricQoE,path = pathgr3+'abrL2A/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='L2A-LL',prefix=group3)

listQoElin = parseLogs(metricQoE,path = pathgr3+'abrLoLP/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='LoL+',prefix=group3)
# Out:
# Count segments: 138
# 521.9472000000002
# Count segments: 118
# 419.22399999999993
# Count segments: 126
# 397.27679999999987
# Count segments: 140
# 402.48879999999997
# Count segments: 119
# 377.83919999999995
# Count segments: 143
# 502.8880000000001
# Count segments: 112
# 316.5951999999999
# Count segments: 191
# 799.4304
# Count segments: 190
# 737.1935999999998
# Count segments: 126
# 406.70799999999997
# Count segments: 204
# 816.4007999999999
# Count segments: 131
# 426.4680000000001
# Count segments: 192
# 729.0871999999999
# Count segments: 150
# 513.0896
# Count segments: 124
# 353.30159999999995
# Count segments: 209
# 855.1663999999997
# Count segments: 193
# 742.6991999999999
# Count segments: 139
# 485.128
# Count segments: 138
# 518.3664
# Count segments: 138
# 520.564
# Count segments: 140
# 416.2200000000001
# Count segments: 138
# 392.324
# Count segments: 129
# 444.3576
# Count segments: 141
# 513.74
# Count segments: 143
# 448.2192
# Count segments: 159
# 529.4088
# Count segments: 114
# 348.6175999999999
# Count segments: 135
# 431.9208000000001
# Count segments: 128
# 409.3479999999999
# Count segments: 140
# 512.5528
# Count segments: 192
# 750.5759999999998
# Count segments: 142
# 499.71680000000015
# Count segments: 130
# 437.0448
# Count segments: 192
# 790.8543999999998
# Count segments: 188
# 735.7511999999999
# Count segments: 129
# 509.93519999999995
# Count segments: 128
# 533.1551999999998
# Count segments: 139
# 557.2104
# Count segments: 130
# 508.1224
# Count segments: 149
# 584.9152
# Count segments: 140
# 556.2312
# Count segments: 129
# 100.79679999999999
# Count segments: 143
# 596.4856
# Count segments: 128
# 488.1335999999999
# Count segments: 129
# 518.5688
# Count segments: 148
# 598.9152
# Count segments: 140
# 333.53600000000006
# Count segments: 137
# 542.6824000000001
# Count segments: 145
# 591.756
# Count segments: 148
# 566.1551999999999
# Count segments: 127
# 467.4624
# Count segments: 130
# 508.3312
# Count segments: 130
# 506.752
# Count segments: 128
# 497.20399999999984
# Count segments: 128
# 74.10479999999995
# Count segments: 124
# 459.5016
# Count segments: 147
# 613.3824
# Count segments: 120
# 436.71759999999983
# Count segments: 128
# 475.13839999999993
# Count segments: 144
# 567.3056
# Count segments: 142
# 552.2176
# Count segments: 133
# 514.6984000000001
# Count segments: 139
# 506.74640000000005
# Count segments: 142
# 568.6248
# Count segments: 132
# 506.2696000000001
# Count segments: 129
# 509.08320000000003
# Count segments: 147
# 586.8648000000001
# Count segments: 130
# 512.9592000000001
# Count segments: 140
# 567.3072
# Count segments: 130
# 518.6424
# Count segments: 150
# 441.8960000000001
# Count segments: 144
# 359.1752
# Count segments: 143
# 382.0760000000001
# Count segments: 153
# 480.13439999999997
# Count segments: 143
# 345.40320000000014
# Count segments: 153
# 501.5696000000001
# Count segments: 157
# 532.8720000000001
# Count segments: 151
# 484.7944000000001
# Count segments: 150
# 467.17440000000005
# Count segments: 154
# 497.0856
# Count segments: 143
# 462.89920000000006
# Count segments: 152
# 480.6991999999999
# Count segments: 151
# 479.0160000000001
# Count segments: 146
# 457.1031999999999
# Count segments: 158
# 471.01200000000017
# Count segments: 153
# 488.6984
# Count segments: 152
# 467.64720000000005
# Count segments: 150
# 492.68160000000006
# Count segments: 154
# 507.0912
# Count segments: 143
# 429.676
# Count segments: 153
# 422.0592000000001
# Count segments: 153
# 493.98
# Count segments: 159
# 541.5912000000001
# Count segments: 152
# 481.83439999999996
# Count segments: 142
# 482.6344000000001
# Count segments: 143
# 502.7064000000001
# Count segments: 139
# 366.25840000000005
# Count segments: 157
# 432.13520000000005
# Count segments: 152
# 480.3927999999999
# Count segments: 152
# 492.7296
# Count segments: 144
# 441.9304000000001
# Count segments: 152
# 483.11920000000003
# Count segments: 152
# 455.44
# Count segments: 159
# 448.6736000000002
# Count segments: 146
# 372.8584000000001

# %%
pathgr4 = "../results-collector/scenario4/" 

group4="scenario-4"

metricQoE = MetricQoElin(name=group4,mi=mi, lbd=lbd, mi_s=mi_s,log_level='info')
#scores = pd.DataFrame()

listQoE = parseLogs(metricQoE,path = pathgr4+'abrBola/',div_by=div_by) 
scores = metricQoE.tabulation(listQoE,scores = scores,abrRule='BOLA',prefix=group4)

listQoElin = parseLogs(metricQoE,path = pathgr4+'abrL2A/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='L2A-LL',prefix=group4)

listQoElin = parseLogs(metricQoE,path = pathgr4+'abrLoLP/2nd/',div_by=div_by)
scores = metricQoE.tabulation(listQoElin,scores = scores,abrRule='LoL+',prefix=group4)
scores.head()
# Out:
# Count segments: 170
# 530.2919999999999
# Count segments: 172
# 519.2832000000001
# Count segments: 173
# 573.1552
# Count segments: 174
# 553.9431999999999
# Count segments: 149
# 340.8312000000001
# Count segments: 170
# 664.0439999999999
# Count segments: 177
# 532.3648000000001
# Count segments: 161
# 545.4495999999999
# Count segments: 173
# 686.5056
# Count segments: 168
# 585.8375999999998
# Count segments: 161
# 591.0136
# Count segments: 171
# 674.4623999999999
# Count segments: 179
# 588.8984
# Count segments: 167
# 684.7464
# Count segments: 176
# 594.872
# Count segments: 180
# 518.512
# Count segments: 146
# 455.4888
# Count segments: 174
# 611.0855999999999
# Count segments: 167
# 673.0408
# Count segments: 163
# 566.1031999999999
# Count segments: 154
# 530.1144
# Count segments: 155
# 470.1791999999999
# Count segments: 151
# 492.3744
# Count segments: 159
# 553.988
# Count segments: 169
# 412.00639999999987
# Count segments: 167
# 495.39600000000013
# Count segments: 155
# 471.61760000000004
# Count segments: 156
# 389.60480000000007
# Count segments: 166
# 670.7144
# Count segments: 164
# 408.0336000000001
# Count segments: 168
# 573.9183999999999
# Count segments: 178
# 597.0831999999998
# Count segments: 162
# 555.1623999999999
# Count segments: 166
# 683.4864
# Count segments: 171
# 667.3792
# Count segments: 176
# 642.4943999999999
# Count segments: 156
# 602.1784
# Count segments: 174
# 627.9008
# Count segments: 145
# 479.13680000000005
# Count segments: 165
# 612.3632000000001
# Count segments: 151
# 500.8328000000001
# Count segments: 169
# 580.8824000000001
# Count segments: 155
# 582.1704
# Count segments: 163
# 578.0096
# Count segments: 167
# 572.1864
# Count segments: 155
# 582.1216
# Count segments: 147
# 524.7064000000001
# Count segments: 165
# 582.1664
# Count segments: 141
# 501.4960000000001
# Count segments: 161
# 602.7928
# Count segments: 144
# 495.10959999999994
# Count segments: 153
# 532.5704000000001
# Count segments: 178
# 160.81920000000002
# Count segments: 154
# 583.7688
# Count segments: 164
# 592.6976000000001
# Count segments: 153
# 511.77759999999995
# Count segments: 172
# 667.872
# Count segments: 143
# 493.1688000000001
# Count segments: 157
# 599.4472
# Count segments: 165
# 590.7432000000001
# Count segments: 142
# 448.5688000000001
# Count segments: 152
# 541.7416000000001
# Count segments: 149
# 483.32640000000004
# Count segments: 133
# 453.5712000000001
# Count segments: 179
# 554.7152
# Count segments: 118
# 405.2024
# Count segments: 148
# 526.3944
# Count segments: 123
# 415.21919999999994
# Count segments: 153
# 536.4
# Count segments: 160
# 573.8504
# Count segments: 174
# 450.6064
# Count segments: 168
# 548.6216
# Count segments: 160
# 475.5648
# Count segments: 163
# 599.9016
# Count segments: 168
# 536.3552
# Count segments: 163
# 526.0128000000001
# Count segments: 163
# 564.4431999999999
# Count segments: 160
# 484.39599999999996
# Count segments: 178
# 438.19919999999996
# Count segments: 165
# 558.7840000000001
# Count segments: 160
# 471.3552
# Count segments: 162
# 481.7776
# Count segments: 171
# 552.2615999999999
# Count segments: 159
# 329.40640000000013
# Count segments: 170
# 542.56
# Count segments: 168
# 528.8576
# Count segments: 160
# 511.17679999999996
# Count segments: 162
# 501.27600000000007
# Count segments: 182
# 446.18560000000014
# Count segments: 181
# 449.26640000000003
# Count segments: 160
# 486.0048
# Count segments: 163
# 357.26400000000007
# Count segments: 163
# 561.1448
# Count segments: 163
# 549.1528
# Count segments: 164
# 565.336
# Count segments: 168
# 514.4512
# Count segments: 171
# 550.1528000000001
# Count segments: 171
# 617.328
# Count segments: 164
# 431.80000000000007
# Count segments: 161
# 483.61760000000004
# Count segments: 177
# 431.548
# Count segments: 168
# 539.3568
# Count segments: 163
# 557.5527999999999
# Count segments: 155
# 438.636
# Count segments: 163
# 564.1616
#   abr Rule  Average value     Metrics
# 0     BOLA        88.5848  scenario-1
# 1     BOLA       402.9912  scenario-1
# 2     BOLA       181.5192  scenario-1
# 3     BOLA       303.1272  scenario-1
# 4     BOLA       173.7336  scenario-1

# %%
scores.head(99)
# Out:
#    abr Rule  Average value                        Metrics
# 0      BOLA        88.5848                     scenario-1
# 1      BOLA       402.9912                     scenario-1
# 2      BOLA       181.5192                     scenario-1
# 3      BOLA       303.1272                     scenario-1
# 4      BOLA       173.7336                     scenario-1
# ..      ...            ...                            ...
# 28     BOLA        88.2000  scenario-1_Smoothness Penalty
# 29     BOLA       114.6000  scenario-1_Smoothness Penalty
# 30     BOLA       129.6000  scenario-1_Smoothness Penalty
# 31     BOLA        40.5000  scenario-1_Smoothness Penalty
# 32     BOLA       112.2000  scenario-1_Smoothness Penalty
#
# [99 rows x 3 columns]

# %% [markdown]
# ## 1.2 QoE

# %%
# filter only QoE metrics
data_filter = ((scores['Metrics']==group1) | (scores['Metrics']==group2) | (scores['Metrics']==group3) | (scores['Metrics']==group4))
score2=scores[data_filter]
score2 = score2.reset_index(drop=True)
#Calc max mean by rule and group 
maxQoE = score2.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score2['Average value'] = score2['Average value'].apply(lambda x: x/maxQoE).values
score2.head()
# Out:
# Average value  mean    725.788183
# dtype: float64
#   abr Rule  Average value     Metrics
# 0     BOLA       0.122053  scenario-1
# 1     BOLA       0.555246  scenario-1
# 2     BOLA       0.250099  scenario-1
# 3     BOLA       0.417652  scenario-1
# 4     BOLA       0.239372  scenario-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")
#sns.set_palette("dark")

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized QoE")
plt.show()
ax.figure.savefig("./graphs/main_QoE"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score2.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized QoE")
plt.show()
# Out:
#                     Average value                     ci_hi     ci_lo
#                              mean count       std
# abr Rule Metrics
# BOLA     scenario-1      0.241522    33  0.108253  0.278457  0.204588
#          scenario-2      0.791268    35  0.233302  0.868559  0.713976
#          scenario-3      0.940977    35  0.105140  0.975810  0.906145
#          scenario-4      0.905055    35  0.129031  0.947803  0.862308
# L2A-LL   scenario-1      0.186159    33  0.079270  0.213205  0.159113
#          scenario-2      0.940693    35  0.092921  0.971477  0.909909
#          scenario-3      1.000000    35  0.217235  1.071969  0.928031
#          scenario-4      0.940077    35  0.130593  0.983342  0.896813
# LoL+     scenario-1      0.180669    33  0.081915  0.208618  0.152721
#          scenario-2      0.601558    35  0.166727  0.656794  0.546322
#          scenario-3      0.827186    35  0.073401  0.851503  0.802868
#          scenario-4      0.820142    35  0.108146  0.855970  0.784314

# %% [markdown]
# ## 1.3 QoE Kernel Density Estimation

# %%
# %matplotlib inline

ax = sns.displot(score2, x="Average value",col="abr Rule", hue="Metrics", kind="kde")

ax.savefig("./graphs/Density1_QoE"+".eps",bbox_inches="tight")

# %%
# %matplotlib inline

ax = sns.displot(score2, x="Average value",col="Metrics", hue="abr Rule", kind="kde")
ax.savefig("./graphs/Density2_QoE"+".eps",bbox_inches="tight")

# %% [markdown]
# ## 1.4 QoE Empirical Cumulative Distributions

# %%
score2.head()
# Out:
#   abr Rule  Average value     Metrics
# 0     BOLA       0.128734  scenario-1
# 1     BOLA       0.585640  scenario-1
# 2     BOLA       0.263789  scenario-1
# 3     BOLA       0.440514  scenario-1
# 4     BOLA       0.252475  scenario-1

# %%
#colors = (250, 70, 50), (350, 70, 50)
# %matplotlib inline

#cmap = sns.blend_palette(colors, input="husl", as_cmap=True)
ax=sns.displot(score2,x="Average value", col="abr Rule", hue="Metrics",kind="ecdf", aspect=.75, linewidth=2)

ax.savefig("./graphs/ECDF1_QoE"+".eps",bbox_inches="tight")

# %%
#colors = (250, 70, 50), (350, 70, 50)
# %matplotlib inline

#cmap = sns.blend_palette(colors, input="husl", as_cmap=True)
ax=sns.displot(score2,x="Average value", col="Metrics", hue="abr Rule",kind="ecdf", aspect=.75, linewidth=2)

ax.savefig("./graphs/ECDF2_QoE"+".eps",bbox_inches="tight")

# %% [markdown]
# ## 1.4 Biterate utility

# %%
comp='_Bitrate Utility'
# filter only QoE metrics
data_filter = ((scores['Metrics']==group1+comp) | (scores['Metrics']==group2+comp) | (scores['Metrics']==group3+comp) | (scores['Metrics']==group4+comp))
score2=scores[data_filter]
score2 = score2.reset_index(drop=True)

score2 = score2.replace(regex={group1+comp: group1,
                               group2+comp: group2,
                               group3+comp: group3,
                               group4+comp: group4})

#Calc max mean by rule and group 
maxQoE = score2.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score2['Average value'] = score2['Average value'].apply(lambda x: x/maxQoE).values
score2.head()
# Out:
# Average value  mean    3903.45433
# dtype: float64
#   abr Rule  Average value     Metrics
# 0     BOLA       0.450305  scenario-1
# 1     BOLA       0.624827  scenario-1
# 2     BOLA       0.466641  scenario-1
# 3     BOLA       0.405969  scenario-1
# 4     BOLA       0.438974  scenario-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
#sns.set_palette("dark")

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized Bitrate Utility value")
plt.show()
ax.figure.savefig("./graphs/brt_utlty"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score2.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized value")
plt.show()
# Out:
#                     Average value                     ci_hi     ci_lo
#                              mean count       std
# abr Rule Metrics
# BOLA     scenario-1      0.495141    33  0.083708  0.523701  0.466581
#          scenario-2      0.980055    35  0.208574  1.049155  0.910956
#          scenario-3      0.727673    35  0.172039  0.784669  0.670678
#          scenario-4      0.787777    35  0.065732  0.809554  0.766000
# L2A-LL   scenario-1      0.321725    33  0.116677  0.361533  0.281916
#          scenario-2      0.703912    35  0.361087  0.823537  0.584286
#          scenario-3      0.439198    35  0.220522  0.512255  0.366140
#          scenario-4      0.723407    35  0.108417  0.759325  0.687489
# LoL+     scenario-1      0.352791    33  0.043863  0.367757  0.337826
#          scenario-2      1.000000    35  0.136573  1.045246  0.954754
#          scenario-3      0.504760    35  0.072104  0.528648  0.480872
#          scenario-4      0.658712    35  0.065314  0.680350  0.637074

# %% [markdown]
# ## 1.5 Smoothness Penalty

# %%
comp='_Smoothness Penalty'
# filter only QoE metrics
data_filter = ((scores['Metrics']==group1+comp) | (scores['Metrics']==group2+comp) | (scores['Metrics']==group3+comp) | (scores['Metrics']==group4+comp))
score2=scores[data_filter]
score2 = score2.reset_index(drop=True)
score2 = score2.replace(regex={group1+comp: group1,
                               group2+comp: group2,
                               group3+comp: group3,
                               group4+comp: group4})

#Calc max mean by rule and group 
maxQoE = score2.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)
# Normalize the average value
score2['Average value'] = score2['Average value'].apply(lambda x: x/maxQoE).values
score2.head()
# Out:
# Average value  mean    725.874225
# dtype: float64
#   abr Rule  Average value     Metrics
# 0     BOLA       0.910418  scenario-1
# 1     BOLA       0.664789  scenario-1
# 2     BOLA       0.613900  scenario-1
# 3     BOLA       0.139531  scenario-1
# 4     BOLA       0.592825  scenario-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")
#sns.set_palette("dark")

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized Smoothness Penalty value")
plt.show()
ax.figure.savefig("./graphs/smts_pnlty"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score2.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized value")
plt.show()
# Out:
#                     Average value                     ci_hi     ci_lo
#                              mean count       std
# abr Rule Metrics
# BOLA     scenario-1      0.990862    33  0.274778  1.084612  0.897111
#          scenario-2      0.732559    35  0.480399  0.891712  0.573406
#          scenario-3      0.410973    35  0.190159  0.473972  0.347975
#          scenario-4      0.547457    35  0.297036  0.645863  0.449050
# L2A-LL   scenario-1      0.254087    33  0.224521  0.330690  0.177483
#          scenario-2      0.076091    35  0.059461  0.095790  0.056392
#          scenario-3      0.072727    35  0.149151  0.122140  0.023314
#          scenario-4      0.117101    35  0.023701  0.124952  0.109249
# LoL+     scenario-1      0.603828    33  0.226950  0.681260  0.526395
#          scenario-2      1.000000    35  0.605847  1.200714  0.799286
#          scenario-3      0.809852    35  0.289301  0.905695  0.714008
#          scenario-4      0.239567    35  0.129047  0.282320  0.196815

# %% [markdown]
# ## 1.6 Rebuffering Penalty

# %%
comp='_Rebuffering Penalty'
# filter only QoE metrics
data_filter = ((scores['Metrics']==group1+comp) | (scores['Metrics']==group2+comp) | (scores['Metrics']==group3+comp) | (scores['Metrics']==group4+comp))
score2=scores[data_filter]
score2 = score2.reset_index(drop=True)
score2 = score2.replace(regex={group1+comp: group1,
                               group2+comp: group2,
                               group3+comp: group3,
                               group4+comp: group4})
#Calc max mean by rule and group 
maxQoE = score2.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)
# Normalize the average value
score2['Average value'] = score2['Average value'].apply(lambda x: x/maxQoE).values
score2.head()
# Out:
# Average value  mean    666.551032
# dtype: float64
#   abr Rule  Average value     Metrics
# 0     BOLA       0.896113  scenario-1
# 1     BOLA       0.325373  scenario-1
# 2     BOLA       0.419066  scenario-1
# 3     BOLA       0.249127  scenario-1
# 4     BOLA       0.653137  scenario-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")
#sns.set_palette("dark")

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized Rebuffering Penalty value")
plt.show()
ax.figure.savefig("./graphs/rbf_pnlty"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score2.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized value")
plt.show()
# Out:
#                     Average value                     ci_hi     ci_lo
#                              mean count       std
# abr Rule Metrics
# BOLA     scenario-1      0.968192    33  0.394194  1.102685  0.833698
#          scenario-2      0.207238    35  0.129284  0.250069  0.164407
#          scenario-3      0.130228    35  0.081139  0.157109  0.103347
#          scenario-4      0.187852    35  0.114409  0.225755  0.149949
# L2A-LL   scenario-1      1.000000    33  0.840341  1.286712  0.713288
#          scenario-2      0.393337    35  0.412827  0.530104  0.256570
#          scenario-3      0.067995    35  0.066671  0.090083  0.045908
#          scenario-4      0.316584    35  0.152315  0.367045  0.266123
# LoL+     scenario-1      0.646878    33  0.244000  0.730127  0.563629
#          scenario-2      0.209454    35  0.104165  0.243963  0.174944
#          scenario-3      0.142288    35  0.072007  0.166143  0.118432
#          scenario-4      0.017252    35  0.023772  0.025128  0.009377

# %% [markdown]
# ## 1.7 Startup Delay

# %%
comp='_Startup Delay'
# filter only QoE metrics
data_filter = ((scores['Metrics']==group1+comp) | (scores['Metrics']==group2+comp) | (scores['Metrics']==group3+comp) | (scores['Metrics']==group4+comp))
score2=scores[data_filter]
score2 = score2.reset_index(drop=True)
score2 = score2.replace(regex={group1+comp: group1,
                               group2+comp: group2,
                               group3+comp: group3,
                               group4+comp: group4})
#Calc max mean by rule and group 
maxQoE = score2.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)
# Normalize the average value
score2['Average value'] = score2['Average value'].apply(lambda x: x/maxQoE).values
score2.head()
# Out:
# Average value  mean    0.925429
# dtype: float64
#   abr Rule  Average value     Metrics
# 0     BOLA       0.673202  scenario-1
# 1     BOLA       0.649429  scenario-1
# 2     BOLA       0.669960  scenario-1
# 3     BOLA       0.786663  scenario-1
# 4     BOLA       1.087064  scenario-1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_theme(style="whitegrid")
#sns.set_palette("dark")

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized Startup Delay value")
plt.show()
ax.figure.savefig("./graphs/sdl_pnlty"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score2.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score2,hue_order=abr_filter,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("Experienced scenarios")
ax.set_ylabel("Normalized value")
plt.show()
# Out:
#                     Average value                     ci_hi     ci_lo
#                              mean count       std
# abr Rule Metrics
# BOLA     scenario-1      0.707485    33  0.236847  0.788294  0.626677
#          scenario-2      1.000000    35  1.054629  1.349393  0.650607
#          scenario-3      0.193825    35  0.044939  0.208713  0.178937
#          scenario-4      0.196666    35  0.040819  0.210189  0.183143
# L2A-LL   scenario-1      0.788365    33  0.228244  0.866239  0.710492
#          scenario-2      0.478759    35  0.160600  0.531965  0.425553
#          scenario-3      0.190831    35  0.033566  0.201951  0.179710
#          scenario-4      0.252516    35  0.138705  0.298468  0.206564
# LoL+     scenario-1      0.719634    33  0.231458  0.798604  0.640663
#          scenario-2      0.453998    35  0.219030  0.526562  0.381435
#          scenario-3      0.184285    35  0.041540  0.198047  0.170523
#          scenario-4      0.192374    35  0.019820  0.198941  0.185808

# %% [markdown]
# ## 1.6 Components of QoE - scenario 1

# %% [markdown]
# ### 1.6.1 Normalize

# %%
# filter only QoE metrics
prefix=group1


data_filter = ((scores['Metrics']==prefix+'_Bitrate Utility') | (scores['Metrics']==prefix+'_Smoothness Penalty') | (scores['Metrics']==prefix+'_Rebuffering Penalty') | (scores['Metrics']==prefix+'_Startup Delay'))

score3=scores[data_filter]
score3 = score3.reset_index(drop=True)

score3 = score3.replace(regex={prefix+'_Bitrate Utility': 'Bitrate Utility',
                               prefix+'_Rebuffering Penalty': 'Rebuffering Penalty',
                               prefix+'_Smoothness Penalty': 'Smoothness Penalty',
                              prefix+'_Startup Delay':'Startup Delay'})


score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']})
# Out:
#                              Average value
#                                       mean
# abr Rule Metrics
# BOLA     Bitrate Utility       1839.622271
#          Rebuffering Penalty   2763.492483
#          Smoothness Penalty     493.057385
#          Startup Delay            0.654727
# L2A-LL   Bitrate Utility       1522.339365
#          Rebuffering Penalty   4094.527768
#          Smoothness Penalty     164.415659
#          Startup Delay            0.729576
# LoL+     Bitrate Utility       1237.001773
#          Rebuffering Penalty   1735.887851
#          Smoothness Penalty     283.472604
#          Startup Delay            0.665970

# %%
#Calc max mean by rule and group 
maxQoE = score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score3['Average value'] = score3['Average value'].apply(lambda x: x/maxQoE).values
score3.head()
# Out:
# Average value  mean    4094.527768
# dtype: float64
#   abr Rule  Average value          Metrics
# 0     BOLA       0.429292  Bitrate Utility
# 1     BOLA       0.595669  Bitrate Utility
# 2     BOLA       0.444865  Bitrate Utility
# 3     BOLA       0.387024  Bitrate Utility
# 4     BOLA       0.418489  Bitrate Utility

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score3,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Components of QoE")
ax.set_ylabel("Normalized value")
plt.show()
ax.figure.savefig("./graphs/scen-1_QoE_cpts"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = score3.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=ci)
stats
# Out:
#                              Average value                     ci_hi     ci_lo
#                                       mean count       std
# abr Rule Metrics
# BOLA     Bitrate Utility          1.000000    33  0.169059  1.057680  0.942320
#          Rebuffering Penalty      0.275114    33  0.112011  0.313331  0.236898
#          Smoothness Penalty       0.265155    33  0.073531  0.290243  0.240068
#          Startup Delay            0.002620    33  0.000877  0.002919  0.002320
# L2A-LL   Bitrate Utility          0.649764    33  0.235645  0.730162  0.569365
#          Rebuffering Penalty      0.284153    33  0.238785  0.365623  0.202683
#          Smoothness Penalty       0.067994    33  0.060082  0.088493  0.047495
#          Startup Delay            0.002919    33  0.000845  0.003207  0.002631
# LoL+     Bitrate Utility          0.712506    33  0.088586  0.742731  0.682282
#          Rebuffering Penalty      0.183812    33  0.069333  0.207468  0.160157
#          Smoothness Penalty       0.161585    33  0.060732  0.182306  0.140864
#          Startup Delay            0.002665    33  0.000857  0.002957  0.002372

# %% [markdown]
# ## 1.7 Components of QoE - scenario 2

# %% [markdown]
# ### 1.7.1 Normalize

# %%
# filter only QoE metrics
prefix=group2
data_filter = ((scores['Metrics']==prefix+'_Bitrate Utility') | (scores['Metrics']==prefix+'_Smoothness Penalty') | (scores['Metrics']==prefix+'_Rebuffering Penalty') | (scores['Metrics']==prefix+'_Startup Delay'))

score3=scores[data_filter]
score3 = score3.reset_index(drop=True)
score3 = score3.replace(regex={prefix+'_Bitrate Utility': 'Bitrate Utility',
                               prefix+'_Rebuffering Penalty': 'Rebuffering Penalty',
                               prefix+'_Smoothness Penalty': 'Smoothness Penalty',
                              prefix+'_Startup Delay':'Startup Delay'})

score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']})
# Out:
#                              Average value
#                                       mean
# abr Rule Metrics
# BOLA     Bitrate Utility       3363.405423
#          Rebuffering Penalty    550.828711
#          Smoothness Penalty     337.234887
#          Startup Delay            0.925429
# L2A-LL   Bitrate Utility       3711.276247
#          Rebuffering Penalty   1039.221908
#          Smoothness Penalty      51.480667
#          Startup Delay            0.681857
# LoL+     Bitrate Utility       3194.668644
#          Rebuffering Penalty   1453.416281
#          Smoothness Penalty     725.874225
#          Startup Delay            0.433800

# %%
#Calc max mean by rule and group 
maxQoE = score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score3['Average value'] = score3['Average value'].apply(lambda x: x/maxQoE).values
score3.head()
# Out:
# Average value  mean    3711.276247
# dtype: float64
#   abr Rule  Average value          Metrics
# 0     BOLA       0.825090  Bitrate Utility
# 1     BOLA       0.913326  Bitrate Utility
# 2     BOLA       1.033735  Bitrate Utility
# 3     BOLA       1.146944  Bitrate Utility
# 4     BOLA       0.633740  Bitrate Utility

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score3,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Components of QoE")
ax.set_ylabel("Normalized value")
plt.show()
ax.figure.savefig("./graphs/scen-2_QoE_cpts"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
stats = score3.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=ci)
stats
# Out:
#                              Average value                     ci_hi     ci_lo
#                                       mean count       std
# abr Rule Metrics
# BOLA     Bitrate Utility          0.980055    35  0.208574  1.049155  0.910956
#          Rebuffering Penalty      0.029158    35  0.018190  0.035184  0.023131
#          Smoothness Penalty       0.097064    35  0.063653  0.118152  0.075976
#          Startup Delay            0.001833    35  0.001933  0.002474  0.001193
# L2A-LL   Bitrate Utility          0.703912    35  0.361087  0.823537  0.584286
#          Rebuffering Penalty      0.055341    35  0.058083  0.074583  0.036098
#          Smoothness Penalty       0.010082    35  0.007879  0.012692  0.007472
#          Startup Delay            0.000878    35  0.000294  0.000975  0.000780
# LoL+     Bitrate Utility          1.000000    35  0.136573  1.045246  0.954754
#          Rebuffering Penalty      0.029469    35  0.014656  0.034325  0.024614
#          Smoothness Penalty       0.132500    35  0.080275  0.159095  0.105906
#          Startup Delay            0.000832    35  0.000402  0.000965  0.000699

# %% [markdown]
# ## 1.8 Components of QoE - scenario 3

# %% [markdown]
# ### 1.8.1 Normalize

# %%
# filter only QoE metrics
prefix=group3
data_filter = ((scores['Metrics']==prefix+'_Bitrate Utility') | (scores['Metrics']==prefix+'_Smoothness Penalty') | (scores['Metrics']==prefix+'_Rebuffering Penalty') | (scores['Metrics']==prefix+'_Startup Delay'))

score3=scores[data_filter]
score3 = score3.reset_index(drop=True)
score3 = score3.replace(regex={prefix+'_Bitrate Utility': 'Bitrate Utility',
                               prefix+'_Rebuffering Penalty': 'Rebuffering Penalty',
                               prefix+'_Smoothness Penalty': 'Smoothness Penalty',
                              prefix+'_Startup Delay':'Startup Delay'})

score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']})
# Out:
#                              Average value
#                                       mean
# abr Rule Metrics
# BOLA     Bitrate Utility       3903.454330
#          Rebuffering Penalty     93.026464
#          Smoothness Penalty     319.255632
#          Startup Delay            0.179371
# L2A-LL   Bitrate Utility       3890.903378
#          Rebuffering Penalty    104.959621
#          Smoothness Penalty      75.805856
#          Startup Delay            0.172800
# LoL+     Bitrate Utility       3261.664003
#          Rebuffering Penalty     16.373937
#          Smoothness Penalty     176.285074
#          Startup Delay            0.174171

# %%
#Calc max mean by rule and group 
maxQoE = score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score3['Average value'] = score3['Average value'].apply(lambda x: x/maxQoE).values
score3.head()
# Out:
# Average value  mean    3903.45433
# dtype: float64
#   abr Rule  Average value          Metrics
# 0     BOLA       1.025847  Bitrate Utility
# 1     BOLA       0.992819  Bitrate Utility
# 2     BOLA       0.953978  Bitrate Utility
# 3     BOLA       0.917685  Bitrate Utility
# 4     BOLA       0.967899  Bitrate Utility

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score3,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Components of QoE")
ax.set_ylabel("Normalized value")
plt.show()
ax.figure.savefig("./graphs/scen-3_QoE_cpts"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
stats = score3.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=ci)
stats
# Out:
#                              Average value                     ci_hi     ci_lo
#                                       mean count       std
# abr Rule Metrics
# BOLA     Bitrate Utility          1.000000    35  0.236423  1.078326  0.921674
#          Rebuffering Penalty      0.025180    35  0.015688  0.030377  0.019982
#          Smoothness Penalty       0.074833    35  0.034626  0.086304  0.063362
#          Startup Delay            0.000488    35  0.000113  0.000526  0.000451
# L2A-LL   Bitrate Utility          0.603564    35  0.303050  0.703963  0.503166
#          Rebuffering Penalty      0.013147    35  0.012891  0.017418  0.008876
#          Smoothness Penalty       0.013243    35  0.027159  0.022240  0.004245
#          Startup Delay            0.000481    35  0.000085  0.000509  0.000453
# LoL+     Bitrate Utility          0.693663    35  0.099089  0.726490  0.660835
#          Rebuffering Penalty      0.027511    35  0.013923  0.032124  0.022899
#          Smoothness Penalty       0.147464    35  0.052678  0.164916  0.130012
#          Startup Delay            0.000464    35  0.000105  0.000499  0.000430

# %% [markdown]
# ## 1.9 Components of QoE - scenario 4

# %% [markdown]
# ### 1.9.1 Normalize

# %%
# filter only QoE metrics
prefix=group4
data_filter = ((scores['Metrics']==prefix+'_Bitrate Utility') | (scores['Metrics']==prefix+'_Smoothness Penalty') | (scores['Metrics']==prefix+'_Rebuffering Penalty') | (scores['Metrics']==prefix+'_Startup Delay'))

score3=scores[data_filter]
score3 = score3.reset_index(drop=True)

score3 = score3.replace(regex={prefix+'_Bitrate Utility': 'Bitrate Utility',
                               prefix+'_Rebuffering Penalty': 'Rebuffering Penalty',
                               prefix+'_Smoothness Penalty': 'Smoothness Penalty',
                              prefix+'_Startup Delay':'Startup Delay'})

score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']})
# Out:
#                              Average value
#                                       mean
# abr Rule Metrics
# BOLA     Bitrate Utility       3830.917876
#          Rebuffering Penalty    115.557022
#          Smoothness Penalty     357.455055
#          Startup Delay            0.182000
# L2A-LL   Bitrate Utility       3781.653552
#          Rebuffering Penalty    211.882966
#          Smoothness Penalty      81.882395
#          Startup Delay            0.233686
# LoL+     Bitrate Utility       3207.416780
#          Rebuffering Penalty     10.169199
#          Smoothness Penalty     154.372511
#          Startup Delay            0.178029

# %%
#Calc max mean by rule and group 
maxQoE = score3.groupby(['abr Rule','Metrics']).agg({'Average value':['mean']}).max()
print(maxQoE)

# Normalize the average value
score3['Average value'] = score3['Average value'].apply(lambda x: x/maxQoE).values
score3.head()
# Out:
# Average value  mean    3830.917876
# dtype: float64
#   abr Rule  Average value          Metrics
# 0     BOLA       0.941412  Bitrate Utility
# 1     BOLA       0.937598  Bitrate Utility
# 2     BOLA       0.983480  Bitrate Utility
# 3     BOLA       0.974827  Bitrate Utility
# 4     BOLA       0.883837  Bitrate Utility

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

abr_filter = ['LoL+','BOLA','L2A-LL']

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="Metrics", y="Average value",hue="abr Rule", data=score3,hue_order=abr_filter,
                 capsize=.05,ci=95,errwidth=0.7)
ax.set_xlabel("Components of QoE")
ax.set_ylabel("Normalized value")
plt.show()
ax.figure.savefig("./graphs/scen-4_QoE_cpts"+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
stats = score3.groupby(['abr Rule','Metrics']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=ci)
stats
# Out:
#                              Average value                     ci_hi     ci_lo
#                                       mean count       std
# abr Rule Metrics
# BOLA     Bitrate Utility          1.000000    35  0.083440  1.027643  0.972357
#          Rebuffering Penalty      0.033550    35  0.020433  0.040319  0.026781
#          Smoothness Penalty       0.092080    35  0.049960  0.108631  0.075528
#          Startup Delay            0.000458    35  0.000095  0.000489  0.000426
# L2A-LL   Bitrate Utility          0.918289    35  0.137624  0.963883  0.872695
#          Rebuffering Penalty      0.056541    35  0.027203  0.065554  0.047529
#          Smoothness Penalty       0.019696    35  0.003986  0.021016  0.018375
#          Startup Delay            0.000588    35  0.000323  0.000695  0.000481
# LoL+     Bitrate Utility          0.836165    35  0.082909  0.863633  0.808698
#          Rebuffering Penalty      0.003081    35  0.004246  0.004488  0.001675
#          Smoothness Penalty       0.040294    35  0.021705  0.047485  0.033103
#          Startup Delay            0.000448    35  0.000046  0.000463  0.000432

# %% [markdown]
# # 2 Bitrate variation analysis by clients

# %% [markdown]
# ## 2.1 Scenario 1

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")


df = parseLogsBy(pathgr1)
df['bitrate'] = df['bitrate']/1e3

g = sns.FacetGrid(df, col="abr Rule")
ax = g.map(sns.barplot, "client", "bitrate",order=df['client'].unique(), capsize=.05,ci=95,errwidth=0.7)
ax.set(xlabel='Clients', ylabel='mean bitrate (kbps)')
plt.show()

df.groupby(['client','abr Rule']).agg({'bitrate':['mean','median','min','max']})
# Out:
#                      bitrate
#                         mean  median    min     max
# client abr Rule
# 0      abrBola   1740.721649  1600.0  700.0  4300.0
#        abrL2A     703.422053   700.0  700.0  1600.0
#        abrLoLP   1518.823529  1600.0  700.0  2800.0
# 1      abrBola   2069.211823  1600.0  700.0  4300.0
#        abrL2A     710.937500   700.0  700.0  2800.0
# ...                      ...     ...    ...     ...
# 31     abrL2A    3657.943925  4300.0  700.0  4300.0
#        abrLoLP   1424.576271  1600.0  700.0  2800.0
# 32     abrBola   1562.758621  1600.0  700.0  4300.0
#        abrL2A     700.000000   700.0  700.0   700.0
#        abrLoLP   1239.737991  1600.0  700.0  2800.0
#
# [99 rows x 4 columns]

# %% [markdown]
# ## 2.2 Scenario 2

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")


df = parseLogsBy(pathgr2)
df['bitrate'] = df['bitrate']/1e3


g = sns.FacetGrid(df, col="abr Rule")
ax = g.map(sns.barplot, "client", "bitrate",order=df['client'].unique(), capsize=.05,ci=95,errwidth=0.7)
ax.set(xlabel='Clients', ylabel='mean bitrate (kbps)')
plt.show()

df.groupby(['client','abr Rule']).agg({'bitrate':['mean','median','min','max']})
# Out:
#                      bitrate
#                         mean  median    min     max
# client abr Rule
# 0      abrBola   3773.319756  4300.0  700.0  4300.0
#        abrL2A    2403.379722   700.0  700.0  4300.0
#        abrLoLP   2676.271186  2800.0  700.0  4300.0
# 1      abrBola   3882.793522  4300.0  700.0  4300.0
#        abrL2A    3989.702517  4300.0  700.0  4300.0
# ...                      ...     ...    ...     ...
# 33     abrL2A    3566.410749  4300.0  700.0  4300.0
#        abrLoLP   2700.000000  2800.0  700.0  4300.0
# 34     abrBola   4200.773694  4300.0  700.0  4300.0
#        abrL2A    3490.388170  4300.0  700.0  4300.0
#        abrLoLP   3185.471698  2800.0  700.0  4300.0
#
# [105 rows x 4 columns]

# %% [markdown]
# ## 2.3 Scenario 3

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")


df = parseLogsBy(pathgr3)
df['bitrate'] = df['bitrate']/1e3


g = sns.FacetGrid(df, col="abr Rule")
ax = g.map(sns.barplot, "client", "bitrate",order=df['client'].unique(), capsize=.05,ci=95,errwidth=0.7)
ax.set(xlabel='Clients', ylabel='mean bitrate (kbps)')
plt.show()

df.groupby(['client','abr Rule']).agg({'bitrate':['mean','median','min','max']})
# Out:
#                      bitrate
#                         mean  median    min     max
# client abr Rule
# 0      abrBola   3904.210526  4300.0  700.0  4300.0
#        abrL2A    4045.783133  4300.0  700.0  4300.0
#        abrLoLP   2900.699301  3550.0  700.0  4300.0
# 1      abrBola   3628.185328  4300.0  700.0  4300.0
#        abrL2A    4007.954545  4300.0  700.0  4300.0
# ...                      ...     ...    ...     ...
# 33     abrL2A    2388.275862   700.0  700.0  4300.0
#        abrLoLP   3213.309353  4300.0  700.0  4300.0
# 34     abrBola   4055.855856  4300.0  700.0  4300.0
#        abrL2A    2364.130435   700.0  700.0  4300.0
#        abrLoLP   3169.064748  4300.0  700.0  4300.0
#
# [105 rows x 4 columns]

# %% [markdown]
# ## 2.4 Scenario 4

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")


df = parseLogsBy(pathgr4)
df['bitrate'] = df['bitrate']/1e3


g = sns.FacetGrid(df, col="abr Rule")
ax = g.map(sns.barplot, "client", "bitrate",order=df['client'].unique(), capsize=.05,ci=95,errwidth=0.7)
ax.set(xlabel='Clients', ylabel='mean bitrate (kbps)')
plt.show()

df.groupby(['client','abr Rule']).agg({'bitrate':['mean','median','min','max']})
# Out:
#                      bitrate
#                         mean  median    min     max
# client abr Rule
# 0      abrBola   3815.056818  4300.0  700.0  4300.0
#        abrL2A    3834.659091  4300.0  700.0  4300.0
#        abrLoLP   3105.769231  2800.0  700.0  4300.0
# 1      abrBola   3934.349030  4300.0  700.0  4300.0
#        abrL2A    4253.846154  4300.0  700.0  4300.0
# ...                      ...     ...    ...     ...
# 33     abrL2A    3970.588235  4300.0  700.0  4300.0
#        abrLoLP   3155.900621  2800.0  700.0  4300.0
# 34     abrBola   4084.347826  4300.0  700.0  4300.0
#        abrL2A    3921.250000  4300.0  700.0  4300.0
#        abrLoLP   3443.465909  4300.0  700.0  4300.0
#
# [105 rows x 4 columns]

# %% [markdown]
# # 3 Analysis of segments biterate

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
df['bitrate'] = df['bitrate']/1e3
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="bitrate", col="abr Rule", hue="scenario",hue_order=order,kind="ecdf",aspect=.75, linewidth=2)
ax.set(xlabel='bitrate (kbps)')
plt.show()

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
df['bitrate'] = df['bitrate']/1e3
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="bitrate", col="abr Rule", hue="scenario",hue_order=order,kind="kde",aspect=.75, linewidth=2)
ax.set(xlabel='bitrate (kbps)')
plt.show()

# %% [markdown]
# # 4. Analysis of buffer occupancy

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="currentBuffer", col="abr Rule", hue="scenario",hue_order=order,kind="ecdf",aspect=.75, linewidth=2)
ax.set(xlabel='buffer occupancy (s)')
plt.show()

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="currentBuffer", col="abr Rule", hue="scenario",hue_order=order,kind="kde",bw_adjust=.5,aspect=.75, linewidth=2)
ax.set(xlabel='buffer occupancy (s)')
plt.show()

# %% [markdown]
# # 5. Analys of rebuffer time

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="rebufferTime", col="abr Rule", hue="scenario",hue_order=order,
               kind="ecdf",aspect=.75, linewidth=2)
ax.set(xlabel='rebuffering time (s)')
#ax.set_yscale('log')
plt.show()

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="rebufferTime", col="abr Rule", hue="scenario",hue_order=order,
               kind="kde",bw_adjust=.5,aspect=.75, linewidth=2)
ax.set(xlabel='rebuffering time (s)')
plt.show()

# %% [markdown]
# # 6. Analys of download time

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="downloadTime", col="abr Rule", hue="scenario",hue_order=order,kind="ecdf",aspect=.75, linewidth=2)
ax.set(xlabel='download time (s)')
plt.show()

# %%
from metrics import parseLogsBy
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

path = "../results-collector"
df = parseLogsBy(path)
order=np.sort(df['scenario'].unique())

ax=sns.displot(df,x="downloadTime", col="abr Rule", hue="scenario",hue_order=order,kind="kde",bw_adjust=.5,aspect=.75, linewidth=2)
ax.set(xlabel='download time (s)')
plt.show()

# %% [markdown]
# # 7. Analys of latency time

# %%
from metrics import parseLogsBy

path = "../results-collector"
df = parseLogsBy(path)

ax=sns.displot(df,x="currentLatency", col="abr Rule", hue="scenario",kind="ecdf",aspect=.75, linewidth=2)
ax.set(xlabel='latency time (s)')
plt.show()

# %%
from metrics import parseLogsBy

path = "../results-collector"
df = parseLogsBy(path)

ax=sns.displot(df,x="currentLatency", col="abr Rule", hue="scenario",kind="kde",aspect=.75, linewidth=2)
ax.set(xlabel='latency time (s)')
plt.show()

# %% [markdown]
# # 8. Analysis traces

# %%
import os
import pandas as pd

# plot graph 
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
sns.set_palette("dark")

# %% [markdown]
# ## 8.1 scaneraio 1

# %%
input_path = '../traces/group1/'

# %matplotlib inline
frames = []
for dirpath, subdirpath, filenames in os.walk(input_path):
        for filename in [f for f in filenames if any(filetype in f.lower() for filetype in ['csv'])]:
            current_file = os.path.join(dirpath, filename)
            #print("input file: {}".format(current_file))
            df = pd.read_csv(current_file)
            df['tracer']= filename.split('.')[4]
            frames.append(df)
result = pd.concat(frames)


result['DL_bitrate']=result['DL_bitrate']/1e3

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x="tracer", y="DL_bitrate",order=np.sort(result['tracer'].unique()), data=result)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.ylabel('Bandwidth (Mbps)', fontsize=15)
plt.xlabel('Id traces', fontsize=15)
plt.legend()
plt.show()
ax.figure.savefig("./graphs/box-gr1"+".eps",bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
result[['DL_bitrate','tracer']].groupby(['tracer']).agg(['median', 'min', 'max','count'])
# Out:
#        DL_bitrate
#            median    min    max count
# tracer
# 00         2.6870  1.602  4.295   355
# 01         2.6040  1.608  4.300   897
# 03         2.2280  1.601  4.269   362
# 05         2.6705  1.628  4.276   152
# 14         2.1225  1.600  4.245   134
# 15         2.5500  1.600  4.285   545
# 16         2.3860  1.603  4.288   627
# 17         2.6665  1.609  4.297   452
# 21         2.4180  1.609  4.236   254
# 22         2.8550  1.602  4.284   399
# 23         2.2320  1.601  4.286   224
# 24         2.4980  1.603  4.297   635
# 25         2.0760  1.603  4.025   142
# 29         2.0530  1.603  4.128   446
# 30         2.3820  1.606  4.295   538
# 32         2.9285  1.608  4.295   280
# 34         2.6895  1.607  4.267    98
# 35         2.3400  1.618  4.248   123
# 38         2.2675  1.601  4.292   112
# 39         3.0030  1.623  4.295   167
# 43         3.0610  1.608  4.283   397
# 56         2.8360  1.650  4.299   129
# 57         2.2800  1.612  4.288   447

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = result[['DL_bitrate','tracer']].groupby(['tracer']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="tracer", y="DL_bitrate", data=result,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("traces")
ax.set_ylabel("BW(kbps)")
plt.show()
# Out:
#          DL_bitrate                          ci_hi        ci_lo
#                mean count         std
# tracer
# 00      2796.028169   355  794.439016  2878.668963  2713.387375
# 01      2738.319955   897  739.127047  2786.689385  2689.950526
# 03      2405.085635   362  682.018189  2475.342661  2334.828609
# 05      2813.361842   152  790.491167  2939.029441  2687.694243
# 14      2271.328358   134  534.038012  2361.749058  2180.907659
# 15      2676.486239   545  761.970998  2740.457996  2612.514481
# 16      2513.837321   627  689.918773  2567.839624  2459.835017
# 17      2758.477876   452  742.134933  2826.894517  2690.061235
# 21      2536.822835   254  687.903417  2621.420563  2452.225107
# 22      2888.375940   399  793.569519  2966.241717  2810.510163
# 23      2370.084821   224  622.818357  2451.646374  2288.523268
# 24      2687.458268   635  808.036813  2750.306400  2624.610135
# 25      2221.190141   142  502.015412  2303.759891  2138.620391
# 29      2205.578475   446  529.601883  2254.729229  2156.427722
# 30      2566.736059   538  741.556068  2629.397582  2504.074537
# 32      2934.514286   280  776.882646  3025.510745  2843.517826
# 34      2758.387755    98  766.920897  2910.227556  2606.547954
# 35      2556.520325   123  752.451832  2689.496624  2423.544027
# 38      2467.285714   112  704.763451  2597.807334  2336.764095
# 39      3039.467066   167  820.560136  3163.918604  2915.015527
# 43      2980.090680   397  769.351762  3055.770099  2904.411261
# 56      2950.689922   129  763.741917  3082.485204  2818.894641
# 57      2492.217002   447  721.422436  2559.095110  2425.338895

# %%
stats[('DL_bitrate', 'mean')].min()
# Out:
# 2205.5784753363228

# %%
stats[('DL_bitrate', 'mean')].max()
# Out:
# 3039.4670658682635

# %% [markdown]
# ## 8.2 scaneraio 2

# %%
input_path = '../traces/group2/'

# %matplotlib inline
frames = []
for dirpath, subdirpath, filenames in os.walk(input_path):
        for filename in [f for f in filenames if any(filetype in f.lower() for filetype in ['csv'])]:
            current_file = os.path.join(dirpath, filename)
            #print("input file: {}".format(current_file))
            df = pd.read_csv(current_file)
            df['tracer']= filename.split('.')[4]
            frames.append(df)
result = pd.concat(frames)


result['DL_bitrate']=result['DL_bitrate']/1e3

sns.set_theme(style="whitegrid")
ax = sns.boxplot(x="tracer", y="DL_bitrate",order=np.sort(result['tracer'].unique()), data=result)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    
plt.ylabel('Bandwidth (Mbps)', fontsize=15)
plt.xlabel('Id traces', fontsize=15)
plt.legend()
plt.show()
ax.figure.savefig("./graphs/box-gr2"+".eps",bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
result[['DL_bitrate','tracer']].groupby(['tracer']).agg(['median', 'min', 'max','count'])
# Out:
#        DL_bitrate
#            median   min     max count
# tracer
# 00        25050.0  3008   87872   418
# 01        42063.0  5211   78343   807
# 04        20528.0  3030  199880  2524
# 06        21585.0  3030   76778   849
# 07        16876.0  3030  103832  2881
# 11        28094.0  3042  105901  1159
# 15        34726.0  3008  173016  1527
# 16        17642.0  3008   70582   924
# 18        20310.0  3053   86888  2773
# 19        22071.5  3008   97804  2112
# 25        22859.5  3019   55752  1726
# 26        23386.0  3034  199693  1268
# 27        46581.0  3009  199946  4349
# 28        31247.5  4956   41570   868
# 29        19150.0  3003  199923  3185
# 30        38797.0  3210   64298  2845
# 32        15601.0  3042   71454   898
# 34        26707.0  3056  199998  4263
# 37        16865.0  3019   79283  2248
# 40        20500.0  3176  102434  1859
# 46        15711.5  3019   74362   750
# 47        18073.0  3109   95612   879
# 48        27132.0  3109  108693  2001
# 56        23162.0  3008   88879  2249
# 57        18179.0  3019   82793  1256
# 58        18827.5  3433   79070   624
# 59        15383.5  3030   70861  1130

# %%
import math 
import scipy.stats as st
import numpy as np

def conf_intervals(stats,ci=0.95):
    ci_hi = []
    ci_lo = []
    for i in stats.index:
        m, c, s = stats.loc[i]
        if(c >= 30):
            ci_=st.norm.interval(alpha=ci, loc=m, scale=s/np.sqrt(c))
        else:
            ci_=st.t.interval(alpha=0.95, df=c-1, loc=m, scale=s/np.sqrt(c))
        ci_hi.append(ci_[1])
        ci_lo.append(ci_[0])

    stats['ci_hi'] = ci_hi
    stats['ci_lo'] = ci_lo
    return stats

stats = result[['DL_bitrate','tracer']].groupby(['tracer']).agg(['mean', 'count', 'std'])
ci = 0.95
stats = conf_intervals(stats,ci=0.95)
print(stats)

fig, bar = plt.subplots(figsize = (11,7))
ax = sns.barplot(x="tracer", y="DL_bitrate", data=result,
                 capsize=.05,ci=ci*100,errwidth=0.7)
ax.set_xlabel("traces")
ax.set_ylabel("BW(kbps)")
plt.show()
# Out:
#           DL_bitrate                             ci_hi         ci_lo
#                 mean count           std
# tracer
# 00      29355.016746   418  19683.603649  31241.984861  27468.048632
# 01      41624.872367   807  15268.665386  42678.318665  40571.426069
# 04      37441.473455  2524  42032.911843  39081.281046  35801.665863
# 06      24196.241461   849  15573.412786  25243.799372  23148.683549
# 07      22536.366539  2881  17662.967837  23181.337468  21891.395610
# 11      33653.150992  1159  24497.829284  35063.523965  32242.778019
# 15      41570.700065  1527  34240.266601  43288.077333  39853.322798
# 16      21176.801948   924  14212.001404  22093.164530  20260.439366
# 18      23157.406058  2773  14008.584297  23678.801709  22636.010408
# 19      31635.930871  2112  23053.742097  32619.132444  30652.729299
# 25      24177.477984  1726  14163.591105  24845.669682  23509.286285
# 26      58237.529968  1268  64516.393847  61788.594370  54686.465567
# 27      66409.430904  4349  57226.141170  68110.209763  64708.652044
# 28      30060.586406   868   7373.211000  30551.093045  29570.079766
# 29      35220.713344  3185  36260.221080  36479.997735  33961.428952
# 30      33409.173286  2845  11412.244071  33828.524599  32989.821974
# 32      18744.506682   898  12053.842352  19532.886376  17956.126987
# 34      43304.327469  4263  42787.200736  44588.739306  42019.915632
# 37      18700.378559  2248  10145.640483  19119.779505  18280.977612
# 40      25475.067778  1859  18210.055363  26302.856800  24647.278757
# 46      18607.573333   750  11424.909230  19425.228561  17789.918106
# 47      23717.105802   879  17943.215307  24903.294883  22530.916721
# 48      33040.306347  2001  21646.344378  33988.744705  32091.867988
# 56      24248.543353  2249  15259.498140  24879.200924  23617.885781
# 57      23039.472930  1256  16620.338728  23958.637217  22120.308643
# 58      23946.556090   624  15924.785041  25196.036280  22697.075900
# 59      17032.190265  1130   9475.016654  17584.635016  16479.745515

# %%
stats[('DL_bitrate', 'mean')].min()
# Out:
# 17032.190265486726

# %%
stats[('DL_bitrate', 'mean')].max()
# Out:
# 66409.43090365602

# %% [markdown]
# # 9. Sample traces bandwidth

# %%
input_path = '../traces/group1/'

# %matplotlib inline
frames = []
for dirpath, subdirpath, filenames in os.walk(input_path):
        for filename in [f for f in filenames if any(filetype in f.lower() for filetype in ['csv'])]:
            current_file = os.path.join(dirpath, filename)
            #print("input file: {}".format(current_file))
            df = pd.read_csv(current_file)
            df['tracer']= filename.split('.')[4]
            frames.append(df)
result = pd.concat(frames)

result[result['tracer']=='29']['DL_bitrate']
df = pd.DataFrame()
df['bandwidth'] = result[result['tracer']=='29']['DL_bitrate']/1e3
df['time'] = range(len(df))

sns.set_theme(style="whitegrid")
sns.set_palette("dark")

ax=sns.lineplot(data=df[:300], x="time", y="bandwidth",palette="tab10", linewidth=.5)
plt.ylabel('Bandwidth (Mbps)', fontsize=15)
plt.xlabel('time (s)', fontsize=15)
plt.legend()
plt.show()
ax.figure.savefig("./graphs/bandwidth-gr1"+".eps",bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
input_path = '../traces/group2/'

# %matplotlib inline
frames = []
for dirpath, subdirpath, filenames in os.walk(input_path):
        for filename in [f for f in filenames if any(filetype in f.lower() for filetype in ['csv'])]:
            current_file = os.path.join(dirpath, filename)
            #print("input file: {}".format(current_file))
            df = pd.read_csv(current_file)
            df['tracer']= filename.split('.')[4]
            frames.append(df)
result = pd.concat(frames)


df = pd.DataFrame()
df['bandwidth'] = result[result['tracer']=='27']['DL_bitrate']/1e3
df['time'] = range(len(df))

sns.set_theme(style="whitegrid")
sns.set_palette("dark")

ax=sns.lineplot(data=df[:300], x="time", y="bandwidth",palette="tab10", linewidth=.5)
plt.ylabel('Bandwidth (Mbps)', fontsize=15)
plt.xlabel('time (s)', fontsize=15)
plt.legend()
plt.show()
ax.figure.savefig("./graphs/bandwidth-gr2"+".eps",bbox_inches="tight")
# Out:
# No handles with labels found to put in legend.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # 9. Only cleaned

# %%
# Load in dataframe all the traces from directory 
from metrics import parseTraces, maker_mahimahi_trace
import pandas as pd
from datetime import datetime
import time

input_path = '../traces/group1/'


df = parseTraces(input_path=input_path,log_level='info')

t = df.time
bw = df['DL_bitrate']

group = "gp1"

# %%
# plot graph 
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline


#current_file = "../traces/group2/A_2017.12.11_13.53.01.csv"
#df = pd.read_csv(current_file)
#t = df.time
#bw = df['DL_bitrate']


ismode = False

print(df['DL_bitrate'].describe())


sns.set_theme(style="whitegrid")
if ismode:
    ax = sns.boxplot(x="NetworkMode", y="DL_bitrate", data=df)
else:
    ax = sns.boxplot(x=df['DL_bitrate'])
    
plt.xlabel('Bandwidth (kbps)', fontsize=12)
plt.legend()
plt.show()
ax.figure.savefig("./graphs/box-"+group+".eps",bbox_inches="tight")
    



modes = ['LTE', 'HSUPA', 'UMTS', 'HSPA+', '5G', 'HSDPA', 'EDGE', 'GPRS']

if ismode:
    for m in modes:
        ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=False,label=m)
else:
    ax2 = sns.kdeplot(df['DL_bitrate'],cumulative=False)

plt.xlabel('Bandwidth (kbps)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()
ax2.figure.savefig("./graphs/density-"+group+".eps",bbox_inches="tight")



if ismode:
    for m in modes:
        ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=True,label=m)
else:
    ax2 = sns.kdeplot(df['DL_bitrate'],cumulative=True)

plt.xlabel('Bandwidth (kbps)', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.legend()
plt.show()
ax2.figure.savefig("./graphs/cdf-"+group+".eps",bbox_inches="tight")


ini=0
tam=224
ax1 = plt.subplot2grid((1, 1), (0, 0), colspan=2)
ax1.plot(range(0,len(t))[ini:tam], bw.values[ini:tam], 'b-', alpha=0.6)
plt.xlabel('time (seg)', fontsize=12)
plt.ylabel('Bandwidth (kbps)', fontsize=12)
plt.legend()
plt.show()
ax1.figure.savefig("./graphs/thrpt-"+group+".eps",bbox_inches="tight")
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# count    7915.000000
# mean     2642.521541
# std       759.335525
# min      1600.000000
# 25%      1988.000000
# 50%      2479.000000
# 75%      3222.000000
# max      4300.000000
# Name: DL_bitrate, dtype: float64
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # 10. Analyse traces

# %%
import os
import pandas as pd
import numpy as np
from metrics import parseTraces

# %%
df = parseTraces(path = '../../../traces/5G-production-dataset/5G-production-dataset/Amazon_Prime/Driving/animated-AdventureTime/1/')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8204b9a447c5> in <module>
# ----> 1 df = parseTraces(path = '../../../traces/5G-production-dataset/5G-production-dataset/Amazon_Prime/Driving/animated-AdventureTime/1/')
#
# TypeError: parseTraces() got an unexpected keyword argument 'path'

# %%
df = df[df['DL_bitrate'] != 0]

# %%
df[df['NetworkMode']=='5G']

# %%
df['DL_bitrate'].describe()

# %%
df['NetworkMode'].unique()

# %%
df[df['NetworkMode']=='5G']['DL_bitrate'].describe()

# %%
df[df['NetworkMode']=='LTE']['DL_bitrate'].describe()

# %%
df[df['NetworkMode']=='HSPA+']['DL_bitrate'].describe()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

#modes = ['LTE', 'HSUPA', 'UMTS', 'HSPA+', '5G', 'HSDPA', 'EDGE', 'GPRS']
modes = ['HSUPA', 'UMTS', 'HSPA+', 'HSDPA', 'EDGE', 'GPRS']

for m in modes:
    ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=False,label=m)

plt.xlabel('bw (kbps)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook


for m in modes:
    ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=True,label=m)
plt.xlabel('bw (kbps)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()

# %%
df.Timestamp

# %%
import seaborn as sns
from datetime import datetime
# %matplotlib notebook
from datetime import datetime
import time

mode = 'HSPA+'

t = df[df['NetworkMode']==mode].Timestamp.apply(lambda x: time.mktime(datetime.strptime(x, "%Y.%m.%d_%H.%M.%S").timetuple()))
bw = df[df['NetworkMode']==mode]['DL_bitrate']

sns.regplot(x=t, y=bw)

# %% [markdown]
# # Prepare traces

# %%
from metrics import parseTraces, maker_mahimahi_trace
import pandas as pd
from datetime import datetime
import time


minimum = 3000
maximum = 200000
input_path = '../../../traces/LTE_Dataset/Dataset/'
output_path = '../traces/group2/'

df = parseTraces(input_path,output_path,minimum,maximum)

t = df.Timestamp.apply(lambda x: time.mktime(datetime.strptime(x, "%Y.%m.%d_%H.%M.%S").timetuple()))
bw = df['DL_bitrate']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

ismode = False

print(df['DL_bitrate'].describe())


sns.set_theme(style="whitegrid")
if ismode:
    ax = sns.boxplot(x="NetworkMode", y="DL_bitrate", data=df)
    plt.legend()
    plt.show()
else:
    ax = sns.boxplot(x=df['DL_bitrate'])
    plt.legend()
    plt.show()
    



modes = ['LTE', 'HSUPA', 'UMTS', 'HSPA+', '5G', 'HSDPA', 'EDGE', 'GPRS']

if ismode:
    for m in modes:
        ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=False,label=m)
else:
    ax2 = sns.kdeplot(df['DL_bitrate'],cumulative=False)

plt.xlabel('bw (kbps)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend()
plt.show()


if ismode:
    for m in modes:
        ax2 = sns.kdeplot(df[df['NetworkMode']==m]['DL_bitrate'],cumulative=True,label=m)
else:
    ax2 = sns.kdeplot(df['DL_bitrate'],cumulative=True)

plt.xlabel('bw (kbps)', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.legend()
plt.show()


ini=0
tam=224
ax1 = plt.subplot2grid((1, 1), (0, 0), colspan=2)
ax1.plot(range(0,len(t))[ini:tam], bw.values[ini:tam], 'b-', alpha=0.6)
plt.xlabel('time (seg)', fontsize=12)
plt.ylabel('bw (kbps)', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# # Filter traces

# %% [raw]
# # Move all file from current_file to topath
#
# import shutil
#
# topath = "../traces/group2/"+"2/"
#
# shutil.move(current_file, topath)

# %%
# Filter traces by rules to put in a set
import shutil
import os
path = "../traces/group1/"
files = os.listdir(path)
    
for file in files:
    #print(files)
    if not os.path.isdir(path+file):
        df = pd.read_csv(path+file)
        est = df['DL_bitrate'].describe()
        #if est[0] >= 300 and est[4]>=9500 and est[5] >= 13000:
        if est[0] >= 150:
            shutil.move(path+file, "../traces/group1/"+"2/")
        else:
            shutil.move(path+file, "../traces/group1/"+"1/")

# %% [markdown]
# # Cooked mahimahi tracer

# %%
IN_FILE = '../traces/group2/'
OUT_FILE = '../traces/cooked_group2/'

maker_mahimahi_trace(IN_FILE,OUT_FILE)

# %% [markdown]
# # Double graph

# %%
df_gp1.head()

# %%
df_gp2.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

ax2 = sns.kdeplot(df_gp1['DL_bitrate']/1000,cumulative=True,label="Group1")
#ax2 = sns.kdeplot(df_gp2['DL_bitrate']/1000,cumulative=True,label="Group2")
#ax2.set(xlim=(1, 150))
plt.xlabel('Bandwidth (Mbps)', fontsize=12)
plt.ylabel('CDF', fontsize=12)
plt.legend()
plt.show()
ax2.figure.savefig("./graphs/cdf-gp1"+".eps",bbox_inches="tight")

# %%
ini=0
tam=224
ax1 = plt.subplot2grid((1, 1), (0, 0), colspan=2)
ax1.plot(range(0,len(df_gp2))[ini:tam], (df_gp2['DL_bitrate']/1000).values[ini:tam], 'b-', alpha=0.6)
plt.xlabel('time (seg)', fontsize=12)
plt.ylabel('Bandwidth (Mbps)', fontsize=12)
plt.legend()
plt.show()
ax1.figure.savefig("./graphs/thrpt-gp2"+".eps",bbox_inches="tight")

# %%
ini=0
tam=224
ax1 = plt.subplot2grid((1, 1), (0, 0), colspan=2)
ax1.plot(range(0,len(df_gp2))[ini:tam], (df_gp1['DL_bitrate']/1000).values[ini:tam], 'b-', alpha=0.6)
plt.xlabel('time (seg)', fontsize=12)
plt.ylabel('Bandwidth (Mbps)', fontsize=12)
plt.legend()
plt.show()
ax1.figure.savefig("./graphs/thrpt-gp1"+".eps",bbox_inches="tight")
