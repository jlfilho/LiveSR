# %% [markdown]
# # Normal continue

# %%
# %matplotlib notebook
from scipy.stats import norm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
mean=10
std=2
size=10000
#r = norm.rvs(loc=mean,scale=std,size=size)
r = np.random.normal(mean, std, size)
ax.hist(r, density=True, bins = 50, histtype='stepfilled', alpha=0.8)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# Out:
# array([ 0.10851139,  0.1622985 , -0.05631565, -0.05544236,  0.0574368 ,
#        -0.08800438,  0.2611511 ,  0.27690756, -0.01224862,  0.13917962])

# %% [markdown]
# # Normal discrete

# %%
# %matplotlib notebook
from scipy.stats import norm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
mean=10
std=2
size=10000
r = norm.rvs(loc=mean,scale=std,size=size)
#r = np.random.normal(mean, std, size)
ax.hist(np.floor(r), density=True, bins = 15, histtype='stepfilled', alpha=0.8)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
# %matplotlib notebook
from scipy.stats import norm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
x = np.arange(0, 20)
mean=10
std=2
size=10000
prob = norm.pdf(x, mean, std)
prob = prob / prob.sum() # normalize the probabilities so their sum is 1
nums = np.random.choice(x, size = size, p = prob)
#print(nums)
plt.hist(nums, bins = 15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.000e+00, 7.000e+00, 1.800e+01, 9.100e+01, 2.510e+02, 6.420e+02,
#         1.232e+03, 1.740e+03, 2.018e+03, 1.740e+03, 1.244e+03, 6.390e+02,
#         2.660e+02, 7.900e+01, 3.200e+01]),
#  array([ 1.        ,  2.06666667,  3.13333333,  4.2       ,  5.26666667,
#          6.33333333,  7.4       ,  8.46666667,  9.53333333, 10.6       ,
#         11.66666667, 12.73333333, 13.8       , 14.86666667, 15.93333333,
#         17.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# # Zipf

# %%
# %matplotlib notebook
from scipy.stats import zipf
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
mean=0
a=1.5
size=60*60*60
r = zipf.rvs(a,loc=mean,size=size)
ax.hist(r, density=True, bins = 50, histtype='stepfilled', alpha=0.8)
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
r[0:100]
# Out:
# array([      1,      54,       1,      16,       7,       6,       1,
#            113,       1,       1,       1,      24,      18,       1,
#              1,       1,      43,       1,       4,       6,       1,
#            184,       2,       1,       1,       9,      19,       9,
#              5,       7,       4,       1,       3,       1,      28,
#              1,     127,       2,       1,       1,       2,      10,
#           8756,       2,       1,       1,       2,       1,       3,
#              1,       2,       2,      22,       1,       1,       1,
#              2,       4,       2,       1,       1,       3,      17,
#              1,      21,       1,     104,      11,     242,       5,
#              1,       1,    1170,       1,       1,       1,       2,
#              3,       2,       1,       1,       2,       1,       1,
#        9096676,      46,       1,       2,       1,       1,       1,
# ...

# %%
rvs(a, loc=0, size=1, random_state=None)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-545244fcc398> in <module>
#      13
#      14 prob = prob / prob.sum() # normalize the probabilities so their sum is 1
# ---> 15 nums = np.random.choice(x, size = size, p = prob)
#      16 #print(nums)
#      17 plt.hist(nums, bins = 15)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# TypeError: object of type 'numpy.float64' has no len()

# %% [markdown]
# # Teste

# %%
from scipy.stats import zipf
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 1)
a = 3
mean, var, skew, kurt = zipf.stats(a, moments='mvsk')
mean, var, skew, kurt
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array(1.36843278), array(inf), array(nan), array(nan))

# %%
x = np.arange(zipf.ppf(0, a),
              zipf.ppf(0.99, a))
ax.plot(x, zipf.pmf(x, a), 'bo', ms=8, label='zipf pmf')
ax.vlines(x, 0, zipf.pmf(x, a), colors='b', lw=5, alpha=0.5)
x
# Out:
# array([0., 1., 2., 3., 4., 5.])

# %%
rv = zipf(a)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
        label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()
